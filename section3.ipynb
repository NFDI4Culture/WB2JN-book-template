# %% [markdown]
# ---
# jupyter: python3
# #code-fold: true
# execute:
#   echo: false
#   output: asis
# lightbox: true
# loop: true
# ---

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
from pathlib import Path
from collections import defaultdict

def query_WB(endpoint, query):
    sparql = SPARQLWrapper(endpoint)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

def get_data(results):
    return [
        {
            "url":           result["item"]["value"],
            "label":         result["itemLabel"]["value"],
            "description":   result["itemDescription"]["value"],
            "photo":         result.get("photo",{}).get("value",""),
            "roomLink":      result.get("parent",{}).get("value",""),
            "room":          result.get("parentLabel",{}).get("value",""),
            "type":          result["itemTypeLabel"]["value"],
            "creator":       result.get("creator",{}).get("value","-"),
        }
        for result in results["results"]["bindings"]
    ]

def group_data(data, castle_label):

    grouped = defaultdict(lambda: defaultdict(dict))
    for entry in data:
        key_castle = (castle_label)
        key_room = (entry["room"], entry["roomLink"])
        # Group multiple photos per artwork if needed
        if entry["label"] not in grouped[key_castle][key_room]:
            grouped[key_castle][key_room][entry["label"]] = {
                "label": entry["label"],
                "wikibase_url": entry["url"],
                "photos": [],
            }
        grouped[key_castle][key_room][entry["label"]]["photos"].append({
            "photo": entry["photo"],
            "photographer": entry["creator"]
        })
    return grouped

def is_supported_image(path):
    ext = Path(path).suffix.lower()
    return ext in [".jpg", ".jpeg", ".png"]

def generate_output(grouped, castle_label):
    print(f"""
# Liste (Schloss): {castle_label}\n
    """)

    for (castle_label), rooms in grouped.items():
        for (room_label, room_url), artworks in rooms.items():
            print(f"""
## {room_label}\\index{{{room_label}}}\n
            """)
            print(f"""
Wikibase-Eintrag: [{room_label} (Raum)]({room_url})\n
            """)
            for art in artworks.values():
                print(f"""
### {art['label']}\\index{{{room_label}!{art['label']}}}\n
                """)
                print(f"Wikibase-Eintrag: [{art['label']} (Kunstwerk)]({art['wikibase_url']})\n")
                for entry in art["photos"]:
                    if not is_supported_image(entry["photo"]):
                        print("*Nicht unterstütztes Bildformat!*")
                    else:
                        print(f"\n![Photo: {entry['photographer']}]({entry['photo']}){{group='room-gallery'}}\n")  
            print("\\newpage")

# %%
castle_ID = "Q68"

# %%
def make_book():

    endpoint = "https://query.kewl.org/sparql"

    query = f"""
PREFIX wd: <https://wikibase.kewl.org/entity/>
PREFIX wdt: <https://wikibase.kewl.org/prop/direct/>
PREFIX p: <https://wikibase.kewl.org/prop/>
PREFIX ps: <https://wikibase.kewl.org/prop/statement/>
PREFIX pq: <https://wikibase.kewl.org/prop/qualifier/>
PREFIX wikibase: <http://wikiba.se/ontology#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX bd: <http://www.bigdata.com/rdf#>


SELECT DISTINCT ?item ?itemLabel ?itemDescription ?itemTypeLabel ?photo ?creator ?parent ?parentLabel ?castleLabel

WHERE {{
  
  VALUES ?itemType {{ wd:Q6 }}
  
  # ?item wdt:P3+ wd:{castle_ID} ;
        wdt:P1 ?itemType .
  OPTIONAL {{ ?item wdt:P3 ?parent . }}
  OPTIONAL {{
    # ?item p:P6 ?statement .
    # ?statement ps:P6 ?photo .
    OPTIONAL {{ ?statement pq:P11 ?creator. }}
  }}
  BIND(wd:{castle_ID} AS ?castle)
  SERVICE wikibase:label {{ bd:serviceParam wikibase:language "de" }}
}}
ORDER BY ?item
    """

    results = query_WB(endpoint, query)
    castle = next((r["castleLabel"]["value"] for r in results["results"]["bindings"] if "castleLabel" in r))
    data = get_data(results)
    grouped = group_data(data, castle)
    generate_output(grouped, castle)

make_book()
# Out:
# # Liste (Schloss): Stuttgart, Schloss Solitude
#
#
#
# ## Sommerspeisesaal\index{Sommerspeisesaal}
#
#
#
# Wikibase-Eintrag: [Sommerspeisesaal (Raum)](https://wikibase.kewl.org/entity/Q71)
#
#
#
# ### Wanddekoration mit Blumengirlanden\index{Sommerspeisesaal!Wanddekoration mit Blumengirlanden}
#
#
# Wikibase-Eintrag: [Wanddekoration mit Blumengirlanden (Kunstwerk)](https://wikibase.kewl.org/entity/Q74)
#
#
# ![Photo: Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013272a.jpg){group='room-gallery'}
#
# \newpage
#
# ## Herrschaftsloge\index{Herrschaftsloge}
#
#
#
# Wikibase-Eintrag: [Herrschaftsloge (Raum)](https://wikibase.kewl.org/entity/Q77)
#
#
#
# ### Die Andacht\index{Herrschaftsloge!Die Andacht}
#
#
# Wikibase-Eintrag: [Die Andacht (Kunstwerk)](https://wikibase.kewl.org/entity/Q78)
#
# *Nicht unterstütztes Bildformat!*
# \newpage
#
# ## Kapellenraum\index{Kapellenraum}
#
#
#
# Wikibase-Eintrag: [Kapellenraum (Raum)](https://wikibase.kewl.org/entity/Q79)
#
#
#
# ### Auferstehung Christi\index{Kapellenraum!Auferstehung Christi}
#
#
# Wikibase-Eintrag: [Auferstehung Christi (Kunstwerk)](https://wikibase.kewl.org/entity/Q80)
#
#
# ![Photo: Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013274a.jpg){group='room-gallery'}
#
#
# ![Photo: Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013273a.jpg){group='room-gallery'}
#
# \newpage
#
# ## Vestibül der Herrschaftsloge\index{Vestibül der Herrschaftsloge}
#
#
#
# Wikibase-Eintrag: [Vestibül der Herrschaftsloge (Raum)](https://wikibase.kewl.org/entity/Q81)
#
#
#
# ### Moses mit den Gesetzestafeln\index{Vestibül der Herrschaftsloge!Moses mit den Gesetzestafeln}
#
#
# Wikibase-Eintrag: [Moses mit den Gesetzestafeln (Kunstwerk)](https://wikibase.kewl.org/entity/Q84)
#
#
# ![Photo: Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013277a.jpg){group='room-gallery'}
#
# \newpage
#
# ## Loggia-Zimmer\index{Loggia-Zimmer}
#
#
#
# Wikibase-Eintrag: [Loggia-Zimmer (Raum)](https://wikibase.kewl.org/entity/Q87)
#
#
#
# ### Ruinenlandschaften\index{Loggia-Zimmer!Ruinenlandschaften}
#
#
# Wikibase-Eintrag: [Ruinenlandschaften (Kunstwerk)](https://wikibase.kewl.org/entity/Q88)
#
#
# ![Photo: Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013289a.jpg){group='room-gallery'}
#
# \newpage
#
# ## Kabinett\index{Kabinett}
#
#
#
# Wikibase-Eintrag: [Kabinett (Raum)](https://wikibase.kewl.org/entity/Q89)
#
#
#
# ### Wanddekoration mit Blumengirlanden\index{Kabinett!Wanddekoration mit Blumengirlanden}
#
#
# Wikibase-Eintrag: [Wanddekoration mit Blumengirlanden (Kunstwerk)](https://wikibase.kewl.org/entity/Q90)
#
#
# ![Photo: Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013290a.jpg){group='room-gallery'}
#
# \newpage
#
# ## Saal\index{Saal}
#
#
#
# Wikibase-Eintrag: [Saal (Raum)](https://wikibase.kewl.org/entity/Q92)
#
#
#
# ### Zwickelfelder der Voute\index{Saal!Zwickelfelder der Voute}
#
#
# Wikibase-Eintrag: [Zwickelfelder der Voute (Kunstwerk)](https://wikibase.kewl.org/entity/Q93)
#
#
# ![Photo: Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013283a.jpg){group='room-gallery'}
#
#
# ![Photo: Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013280a.jpg){group='room-gallery'}
#
#
# ### Die Regierung Herzog Carl Eugens befördert das Wohlergehen des Landes\index{Saal!Die Regierung Herzog Carl Eugens befördert das Wohlergehen des Landes}
#
#
# Wikibase-Eintrag: [Die Regierung Herzog Carl Eugens befördert das Wohlergehen des Landes (Kunstwerk)](https://wikibase.kewl.org/entity/Q94)
#
#
# ![Photo: Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013282a.jpg){group='room-gallery'}
#
#
# ![Photo: Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013279a.jpg){group='room-gallery'}
#
#
# ![Photo: Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013280a.jpg){group='room-gallery'}
#
#
# ![Photo: Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013281a.jpg){group='room-gallery'}
#
# \newpage
#
# ## Palmenzimmer\index{Palmenzimmer}
#
#
#
# Wikibase-Eintrag: [Palmenzimmer (Raum)](https://wikibase.kewl.org/entity/Q96)
#
#
#
# ### Aurora\index{Palmenzimmer!Aurora}
#
#
# Wikibase-Eintrag: [Aurora (Kunstwerk)](https://wikibase.kewl.org/entity/Q97)
#
#
# ![Photo: Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013286a.jpg){group='room-gallery'}
#
# \newpage

# %%
# Query Link

# https://query.kewl.org/#PREFIX%20wd%3A%20%3Chttps%3A%2F%2Fwikibase.kewl.org%2Fentity%2F%3E%0APREFIX%20wdt%3A%20%3Chttps%3A%2F%2Fwikibase.kewl.org%2Fprop%2Fdirect%2F%3E%0APREFIX%20p%3A%20%3Chttps%3A%2F%2Fwikibase.kewl.org%2Fprop%2F%3E%0APREFIX%20ps%3A%20%3Chttps%3A%2F%2Fwikibase.kewl.org%2Fprop%2Fstatement%2F%3E%0APREFIX%20pq%3A%20%3Chttps%3A%2F%2Fwikibase.kewl.org%2Fprop%2Fqualifier%2F%3E%0APREFIX%20wikibase%3A%20%3Chttp%3A%2F%2Fwikiba.se%2Fontology%23%3E%0APREFIX%20rdfs%3A%20%3Chttp%3A%2F%2Fwww.w3.org%2F2000%2F01%2Frdf-schema%23%3E%0APREFIX%20bd%3A%20%3Chttp%3A%2F%2Fwww.bigdata.com%2Frdf%23%3E%0A%0A%0ASELECT%20DISTINCT%20%3Fitem%20%3FitemLabel%20%3FitemDescription%20%3FitemTypeLabel%20%3Fphoto%20%3Fcreator%20%3Fparent%20%3FparentLabel%20%3FcastleLabel%0A%0AWHERE%20%7B%0A%20%20%0A%20%20VALUES%20%3FitemType%20%7B%20wd%3AQ6%20%7D%0A%20%20%0A%20%20%3Fitem%20wdt%3AP3%2B%20wd%3AQ68%20%3B%0A%20%20%20%20%20%20%20%20wdt%3AP1%20%3FitemType%20.%0A%20%20OPTIONAL%20%7B%20%3Fitem%20wdt%3AP3%20%3Fparent%20.%20%7D%0A%20%20OPTIONAL%20%7B%0A%20%20%20%20%3Fitem%20p%3AP6%20%3Fstatement%20.%0A%20%20%20%20%3Fstatement%20ps%3AP6%20%3Fphoto%20.%0A%20%20%20%20OPTIONAL%20%7B%20%3Fstatement%20pq%3AP11%20%3Fcreator.%20%7D%0A%20%20%7D%0A%20%20BIND%28wd%3AQ68%20AS%20%3Fcastle%29%0A%20%20SERVICE%20wikibase%3Alabel%20%7B%20bd%3AserviceParam%20wikibase%3Alanguage%20%22de%22%20%7D%0A%7D%0AORDER%20BY%20%3Fitem
