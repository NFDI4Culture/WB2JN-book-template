# %% [markdown]
# ---
# title: "Die Räume"
# jupyter: python3
# #code-fold: true
# execute:
#   echo: false
#   output: asis
# ---

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pprint 
from pathlib import Path
from collections import defaultdict

def query_WB(endpoint, query):

    # Initialize the wrapper
    sparql = SPARQLWrapper(endpoint)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)

    # Fetch and parse results
    results = sparql.query().convert()

    return results 

def get_data(results):

    grouped = defaultdict(list)

    # Display results
    for result in results["results"]["bindings"]:
        url = result["item"]["value"]
        label = result.get("itemLabel", {}).get("value", "")
        photo = result.get("photo", {}).get("value", "")
        descr = result.get("itemDescription", {}).get("value", "")
        room = result["roomLabel"]["value"]
        photographer = result.get("creator", {}).get("value", "") 

        key = (url, room, label, descr)

        grouped[key].append({
          "photo": photo,
          "photographer": photographer
        })

    return grouped

def is_supported_image(path):
    ext = Path(path).suffix.lower()
    return ext in [".jpg", ".jpeg", ".png"]

def generate_output(grouped):

    for (url, room, label, descr), entries in grouped.items():
            
        print(f"""
## {room}
[{url}]({url})
        """)

        for entry in entries:
            image_url = entry["photo"]
            if not is_supported_image(image_url):
                continue  # skip .BMPs
            print(f"""
### {label}
![{entry['photographer']}]({entry['photo']})
            """)

# %%
def make_book():

    endpoint_url = "https://query.kewl.org/sparql"

    query = """
        PREFIX wd: <https://wikibase.kewl.org/entity/>
        PREFIX wdt: <https://wikibase.kewl.org/prop/direct/>
        PREFIX p: <https://wikibase.kewl.org/prop/>
        PREFIX ps: <https://wikibase.kewl.org/prop/statement/>
        PREFIX pq: <https://wikibase.kewl.org/prop/qualifier/>
        PREFIX wikibase: <http://wikiba.se/ontology#>
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX bd: <http://www.bigdata.com/rdf#>

        SELECT ?item ?itemLabel ?photo ?itemDescription ?roomLabel ?creator WHERE {
            VALUES ?castles { wd:Q68 wd:Q10 }
            # ?item wdt:P3+ ?castles ;
                    wdt:P3 ?room ;
                    wdt:P1 wd:Q6 .
            # ?item p:P6 ?statement .
            # ?statement ps:P6 ?photo .
            OPTIONAL { ?statement pq:P11 ?creator. }

            SERVICE wikibase:label {
                bd:serviceParam wikibase:language "de"
            }
        }
    """


    results = query_WB(endpoint_url,query)
    grouped = get_data(results)
    generate_output(grouped)

make_book()
# Out:
# ## Zelle 2
# [https://wikibase.kewl.org/entity/Q25](https://wikibase.kewl.org/entity/Q25)
#
#
# ### Die Wände
# ![](https://previous.bildindex.de/bilder/fmd10045401a.jpg)
#
#
# ### Die Wände
# ![](https://previous.bildindex.de/bilder/fmd10045403a.jpg)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045400a.jpg)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045402a.jpg)
#
#
# ## Zelle 2
# [https://wikibase.kewl.org/entity/Q26](https://wikibase.kewl.org/entity/Q26)
#
#
# ### Die Decke
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045399a.jpg)
#
#
# ## Zelle 8
# [https://wikibase.kewl.org/entity/Q28](https://wikibase.kewl.org/entity/Q28)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045374a.jpg)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045373a.jpg)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045372a.jpg)
#
#
# ## Zelle 3
# [https://wikibase.kewl.org/entity/Q30](https://wikibase.kewl.org/entity/Q30)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045408a.jpg)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045405a.jpg)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045407a.jpg)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045406a.jpg)
#
#
# ## Zelle 3
# [https://wikibase.kewl.org/entity/Q31](https://wikibase.kewl.org/entity/Q31)
#
#
# ### Die Decke
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045404a.jpg)
#
#
# ## Zelle 13
# [https://wikibase.kewl.org/entity/Q33](https://wikibase.kewl.org/entity/Q33)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045389a.jpg)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045390a.jpg)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045388a.jpg)
#
#
# ## Zelle 13
# [https://wikibase.kewl.org/entity/Q34](https://wikibase.kewl.org/entity/Q34)
#
#
# ### Die Decke
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045387a.jpg)
#
#
# ## Zelle 9
# [https://wikibase.kewl.org/entity/Q36](https://wikibase.kewl.org/entity/Q36)
#
#
# ### Die Decke
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045378a.jpg)
#
#
# ## Zelle 9
# [https://wikibase.kewl.org/entity/Q37](https://wikibase.kewl.org/entity/Q37)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045375a.jpg)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045376a.jpg)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045377a.jpg)
#
#
# ## Zelle 14
# [https://wikibase.kewl.org/entity/Q39](https://wikibase.kewl.org/entity/Q39)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045397a.jpg)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045396a.jpg)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045398a.jpg)
#
#
# ## Zelle 12
# [https://wikibase.kewl.org/entity/Q41](https://wikibase.kewl.org/entity/Q41)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045385a.jpg)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045384a.jpg)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045382a.jpg)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045383a.jpg)
#
#
# ## Zelle 12
# [https://wikibase.kewl.org/entity/Q42](https://wikibase.kewl.org/entity/Q42)
#
#
# ### Die Decke
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045386a.jpg)
#
#
# ## Zelle 15
# [https://wikibase.kewl.org/entity/Q44](https://wikibase.kewl.org/entity/Q44)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045393a.jpg)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045395a.jpg)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045394a.jpg)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045392a.jpg)
#
#
# ## Zelle 32
# [https://wikibase.kewl.org/entity/Q47](https://wikibase.kewl.org/entity/Q47)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045351a.jpg)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045350a.jpg)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045349a.jpg)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045348a.jpg)
#
#
# ## Zelle 32
# [https://wikibase.kewl.org/entity/Q48](https://wikibase.kewl.org/entity/Q48)
#
#
# ### Die Decke
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045347a.jpg)
#
#
# ## Zelle 29
# [https://wikibase.kewl.org/entity/Q50](https://wikibase.kewl.org/entity/Q50)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045360a.jpg)
#
#
# ## Zelle 29
# [https://wikibase.kewl.org/entity/Q51](https://wikibase.kewl.org/entity/Q51)
#
#
# ### Die Decke
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045358a.jpg)
#
#
# ## Zelle 34
# [https://wikibase.kewl.org/entity/Q53](https://wikibase.kewl.org/entity/Q53)
#
#
# ### Die Decke
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045339a.jpg)
#
#
# ## Zelle 34
# [https://wikibase.kewl.org/entity/Q54](https://wikibase.kewl.org/entity/Q54)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045337a.jpg)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045341a.jpg)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045338a.jpg)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045336a.jpg)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045340a.jpg)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045335a.jpg)
#
#
# ## Zelle 36
# [https://wikibase.kewl.org/entity/Q56](https://wikibase.kewl.org/entity/Q56)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045364a.jpg)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045365a.jpg)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045363a.jpg)
#
#
# ## Zelle 36
# [https://wikibase.kewl.org/entity/Q57](https://wikibase.kewl.org/entity/Q57)
#
#
# ### Die Decke
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045361a.jpg)
#
#
# ## Zelle 31
# [https://wikibase.kewl.org/entity/Q59](https://wikibase.kewl.org/entity/Q59)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045357a.jpg)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045354a.jpg)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045356a.jpg)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045352a.jpg)
#
#
# ### Die Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045353a.jpg)
#
#
# ## Zelle 31
# [https://wikibase.kewl.org/entity/Q60](https://wikibase.kewl.org/entity/Q60)
#
#
# ### Die Decke
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045355a.jpg)
#
#
# ## Zelle 33
# [https://wikibase.kewl.org/entity/Q62](https://wikibase.kewl.org/entity/Q62)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045343a.jpg)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045344a.jpg)
#
#
# ### Die Wände
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045345a.jpg)
#
#
# ## Zelle 33
# [https://wikibase.kewl.org/entity/Q63](https://wikibase.kewl.org/entity/Q63)
#
#
# ### Die Decke
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045346a.jpg)
#
#
# ## Sommerspeisesaal
# [https://wikibase.kewl.org/entity/Q72](https://wikibase.kewl.org/entity/Q72)
#
#
# ### Wanddekoration mit Blumengirlanden
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013272a.jpg)
#
#
# ## Herrschaftsloge
# [https://wikibase.kewl.org/entity/Q76](https://wikibase.kewl.org/entity/Q76)
#
#
# ## Kapellenraum
# [https://wikibase.kewl.org/entity/Q78](https://wikibase.kewl.org/entity/Q78)
#
#
# ### Auferstehung Christi
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013274a.jpg)
#
#
# ### Auferstehung Christi
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013273a.jpg)
#
#
# ## Vestibül der Herrschaftsloge
# [https://wikibase.kewl.org/entity/Q80](https://wikibase.kewl.org/entity/Q80)
#
#
# ### Moses mit den Gesetzestafeln
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013277a.jpg)
#
#
# ## Das Vorzimmer der Äbtissin
# [https://wikibase.kewl.org/entity/Q12](https://wikibase.kewl.org/entity/Q12)
#
#
# ### Die Deckenmalereireste
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045421a.jpg)
#
#
# ## Die Barbarakapelle
# [https://wikibase.kewl.org/entity/Q14](https://wikibase.kewl.org/entity/Q14)
#
#
# ### Die Decke
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045418a.jpg)
#
#
# ## Die sog. Alte Schule
# [https://wikibase.kewl.org/entity/Q21](https://wikibase.kewl.org/entity/Q21)
#
#
# ### Die Decke
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045409a.jpg)
#
#
# ## Die sog. Alte Schule
# [https://wikibase.kewl.org/entity/Q22](https://wikibase.kewl.org/entity/Q22)
#
#
# ### Die Wandmalreireste
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045410a.jpg)
#
#
# ### Die Wandmalreireste
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045411a.jpg)
#
#
# ## Der Winterremter
# [https://wikibase.kewl.org/entity/Q65](https://wikibase.kewl.org/entity/Q65)
#
#
# ### Die ältere Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045436a.jpg)
#
#
# ### Die ältere Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045435a.jpg)
#
#
# ### Die ältere Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045434a.jpg)
#
#
# ### Die ältere Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045433a.jpg)
#
#
# ### Die ältere Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045437a.jpg)
#
#
# ### Die ältere Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045427a.jpg)
#
#
# ### Die ältere Wandmalerei
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045438a.jpg)
#
#
# ## Der Winterremter
# [https://wikibase.kewl.org/entity/Q66](https://wikibase.kewl.org/entity/Q66)
#
#
# ### Die Wandgestaltung
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045425a.jpg)
#
#
# ### Die Wandgestaltung
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045426a.jpg)
#
#
# ## Der Winterremter
# [https://wikibase.kewl.org/entity/Q67](https://wikibase.kewl.org/entity/Q67)
#
#
# ### Die Decke
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045430a.jpg)
#
#
# ### Die Decke
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045441a.jpg)
#
#
# ### Die Decke
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045431a.jpg)
#
#
# ### Die Decke
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045428a.jpg)
#
#
# ### Die Decke
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045429a.jpg)
#
#
# ### Die Decke
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045439a.jpg)
#
#
# ### Die Decke
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045432a.jpg)
#
#
# ### Die Decke
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10045440a.jpg)
#
#
# ## Loggia-Zimmer
# [https://wikibase.kewl.org/entity/Q84](https://wikibase.kewl.org/entity/Q84)
#
#
# ### Ruinenlandschaften
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013289a.jpg)
#
#
# ## Kabinett
# [https://wikibase.kewl.org/entity/Q86](https://wikibase.kewl.org/entity/Q86)
#
#
# ### Wanddekoration mit Blumengirlanden
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013290a.jpg)
#
#
# ## Saal
# [https://wikibase.kewl.org/entity/Q89](https://wikibase.kewl.org/entity/Q89)
#
#
# ### Zwickelfelder der Voute
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013280a.jpg)
#
#
# ### Zwickelfelder der Voute
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013283a.jpg)
#
#
# ## Saal
# [https://wikibase.kewl.org/entity/Q90](https://wikibase.kewl.org/entity/Q90)
#
#
# ### Die Regierung Herzog Carl Eugens befördert das Wohlergehen des Landes
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013282a.jpg)
#
#
# ### Die Regierung Herzog Carl Eugens befördert das Wohlergehen des Landes
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013281a.jpg)
#
#
# ### Die Regierung Herzog Carl Eugens befördert das Wohlergehen des Landes
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013280a.jpg)
#
#
# ### Die Regierung Herzog Carl Eugens befördert das Wohlergehen des Landes
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013279a.jpg)
#
#
# ## Palmenzimmer
# [https://wikibase.kewl.org/entity/Q93](https://wikibase.kewl.org/entity/Q93)
#
#
# ### Aurora
# ![Bunz, Achim](https://previous.bildindex.de/bilder/fmd10013286a.jpg)
